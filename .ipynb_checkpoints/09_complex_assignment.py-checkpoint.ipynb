# %%
# 1: Create complex number 5 + 3j

# %%
z = complex(5,3)
print("complex numbeer:",z)
print("real part:",z.real)
print("Imaginary part:",z.imag)
# Out:
# complex numbeer: (5+3j)
# real part: 5.0
# Imaginary part: 3.0

# %%
# 2: Find the real part of complex number 7 - 2j

# %%
a =complex(7-2j)
print("real part:",a.real)
# Out:
# real part: 7.0

# %%
# 3: Find the imaginary part of complex number 4 + 6j

# %%
b = complex(4+6j)
print("imaginary part:",b.imag)
# Out:
# imaginary part: 6.0

# %%
4 # Add two complex numbers: (3 + 2j) and (1 + 4j)

# %%
z = (3+2j) + (1+4j)
print(z)
# Out:
# (4+6j)

# %%
z1 = 3 + 2j
z2 = 1 + 4j

result = z1 + z2
print("Sum:", result)
# Out:
# Sum: (4+6j)

# %%
# 5: Multiply two complex numbers: (2 + 3j) and (1 + 2j)

# %%
 a =(2 + 3j) * (1 + 2j) 
print(a)
# Out:
# (-4+7j)

# %%
# 6: Find the magnitude of complex number 6 + 8j  ∣z∣=a2+b2

# %%
b =6 + 8j
print(abs(b))
# Out:
# 10.0

# %%
#7   Find the conjugate of complex number 5 - 7j

# %%
z = 5 - 7j
print(z.conjugate())
# Out:
# (5+7j)

# %%
#  8: Subtract complex numbers: (10 + 5j) - (3 + 2j)

# %%
n = (10 + 5j) - (3 + 2j)
print(n)
# Out:
# (7+3j)

# %%
# 9: Divide complex numbers: (8 + 6j) / (2 + 1j)

# %%
n =(8 + 6j) / (2 + 1j)
print(n)
# Out:
# (4.4+0.8j)

# %%
# 10: Find the phase angle of complex number 1 + 1j

# %%
import cmath
z =  1 + 1j
phase = cmath.phase(z)
print(phase)
# Out:
# 0.7853981633974483

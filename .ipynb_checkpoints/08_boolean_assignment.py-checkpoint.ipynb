# %%
# check if 25 is greater than 20 and less than 30

# %%
a = 25
b = 20
c = 30
if a > b and a < c:
    print("Condition is True:", a)
else:
    print("Condition is not True:")
# Out:
# Condition is True: 25

# %%
# 2: Check if string "python" is equal to "Python" (case sensitive)

# %%
str1 = "Pythhon"
str2 = "Pythhon"
if str1 == str2:
    print("string is equal")
else:
    print("string is not equal")
# Out:
# string is equal

# %%
# 3: Check if 15 is divisible by both 3 and 5

# %%
num = 15
if num % 3  == 0 and  num % 5 == 0:
    print ("num is divisible by 3 and 5")
else:
    print("num is not divisible 3 and 5")
# Out:
# num is divisible by 3 and 5

# %%
#  Question 4: Check if 7 is not equal to 8

# %%
a =7
b =8
if a!= b:
    print("7 is not equal to 8")
else:
    print("7 is equal to 8")
# Out:
# 7 is not equal to 8

# %%
# 5: Check if 100 is greater than 50 or less than 25

# %%
n = 100
n1 = 50
n2 = 25
if n > n1 and n < n2:
    print ("true")
else:
    print("fales")
# Out:
# fales

# %%
# 6: Check if 0 is falsy in Python

# %%
if 0:
    print("0 is falsy")
else:
    print("0 is not falsy")
# Out:
# 0 is not falsy

# %%
# Question 7: Check if empty string "" is falsy in Python

# %%
if "":
    print("falsy")
else:
    print("empty is not falsy")
# Out:
# empty is not falsy

# %%
# 8: Check if 42 is truthy in Python

# %%
if 42:
    print("42 is truthy in python")
else:
    print("42 is not truthy")
# Out:
# 42 is truthy in python

# %%
# 9: Check if 10 is between 5 and 15 (inclusive)

# %%
if 10 in range(5,15):
    print("Truth")
else:
    print("Fales")
# Out:
# Truth

# %%
# Question 10: Check if 3.14 is greater than 3 and less than 4

# %%
n = 3.14
if n > 3 and n < 4:
    print("Truth")
else:
    print("fales")
# Out:
# Truth

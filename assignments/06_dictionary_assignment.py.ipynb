# %% [markdown]
# <!-- 1: Create a dictionary of student names and their ages -->

# %%
student = {"arvind": 20,"nani":40}
print(student)
# Out:
# {'arvind': 20, 'nani': 40}

# %%
# Question 2: Add a new key-value pair to dictionary {'a': 1, 'b': 2, 'c': 3}   adding the both key and value

# %%
nani ={'a': 1, 'b': 2, 'c': 3}
nani["d"] = 4
print(nani)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
# 3: Get all keys from dictionary {'name': 'John', 'age': 25, 'city': 'New York'}

# %%
nani = {'name': 'John', 'age': 25, 'city': 'New York'}
nani1 = nani.keys()
nani2 = nani.values()
print(f"{nani1}  {nani2}")
# Out:
# dict_keys(['name', 'age', 'city'])  dict_values(['John', 25, 'New York'])

# %%
# Question 4: Get all values from dictionary {'python': 3, 'java': 2, 'c++': 1}
# print("\nQuestion 4: Get all values from dictionary {'python': 3, 'java': 2, 'c++': 1}")

# %%
get =  {'python': 3, 'java': 2, 'c++': 1}
get1 = get.values()
print(get1)
# Out:
# dict_values([3, 2, 1])

# %%
#  5: Check if key 'age' exists in {'name': 'Alice', 'age': 30, 'city': 'London'}

# %%
n ={'name': 'Alice', 'age': 30, 'city': 'London'}
print("age" in n)
# Out:
# True

# %%
# 6: Remove key 'temp' from {'a': 1, 'b': 2, 'temp': 3, 'c': 4}

# %%
nani ={'a': 1, 'b': 2, 'temp': 3, 'c': 4}
# nani.pop("temp")
del nani["temp"]
nani
# Out:
# {'a': 1, 'b': 2, 'c': 4}

# %%
# 7: Find the sum of all values in {'math': 85, 'science': 92, 'english': 78}

# %%
valu =  {'math': 85, 'science': 92, 'english': 78}
res = sum(valu.values())
res
# Out:
# 255

# %%
# marks = {
#     'math': 85,
#     'science': 92,
#     'english': 78
# }

# total = sum(marks.values())

# print(total)

# %%
# 8: Create a dictionary with squares of numbers 1 to 5

# %%
dis={}
for i in range(1,6):
    dis = i**2
print(squ)
# Out:
# 25

# %%
# 9: Count frequency of each character in string "hello"

# %%
fre ="hello"
frequency = {}
for text in fre:
    if text in frequency:
        frequency[text] +=1
    else:
        frequency[text] =1
print(frequency)
# Out:
# {'h': 1, 'e': 1, 'l': 2, 'o': 1}

# %%
# 10: Merge two dictionaries {'a': 1, 'b': 2} and

# %%
d1={'a': 1, 'b': 2}
d2={'c': 3, 'd': 4}
# d1.update(d2)
res =d1|d2
print(res)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
# 11: Create a nested dictionary: {'person': {'name': 'Alice', 'age': 25}}

# %%
nest = {'person': {'name': 'Alice', 'age': 25}}
nest
# Out:
# {'person': {'name': 'Alice', 'age': 25}}

# %%
# Access nested value 'name' from {'person': {'name': 'Alice', 'age': 25}}

# %%
nest= {'person': {'name': 'Alice', 'age': 25}}
print(nest["person"]["name"])
# Out:
# Alice

# %%
# 13: Create a dictionary with list values: {'fruits': ['apple', 'banana'], 'colors': ['red', 'blue']}

# %%
dic = {'fruits': ['apple', 'banana'], 'colors': ['red', 'blue']}
print(dic)
# Out:
# {'fruits': ['apple', 'banana'], 'colors': ['red', 'blue']}

# %%
# Add 'orange' to the 'fruits' list in nested dictionary

# %%
dic = {'fruits': ['apple', 'banana'], 'colors': ['red', 'blue']}
dic["fruits"].append('orange')
print(dic)
# Out:
# {'fruits': ['apple', 'banana', 'orange'], 'colors': ['red', 'blue']}

# %%
# 15: Create a dictionary with tuple values: {'coordinates': (10, 20), 'rgb': (255, 0, 0)}

# %%
tupl = {'coordinates': (10, 20), 'rgb': (255, 0, 0)}
tupl
# Out:
# {'coordinates': (10, 20), 'rgb': (255, 0, 0)}

# %%
# 16: Extract first coordinate from nested tuple

# %%
tupl = {'coordinates': (10, 20), 'rgb': (255, 0, 0)}
print(tupl["coordinates"][0])
# Out:
# 10

# %%
# 17: Create a dictionary with set values: {'vowels': {'a', 'e', 'i'}, 'consonants': {'b', 'c', 'd'}}

# %%
sets = {'vowels': {'a', 'e', 'i'}, 'consonants': {'b', 'c', 'd'}}
print(sets)
# Out:
# {'vowels': {'i', 'a', 'e'}, 'consonants': {'b', 'd', 'c'}}

# %%
# 18: Add 'o' to vowels set in nested dictionary

# %%
sets = {'vowels': {'a', 'e', 'i'}, 'consonants': {'b', 'c', 'd'}}
sets['vowels'].add('o')
print(sets)
# Out:
# {'vowels': {'i', 'a', 'e', 'o'}, 'consonants': {'b', 'd', 'c'}}

# %%
# 19: Create a 3-level nested dictionary: {'company': {'department': {'employee': {'name': 'John', 'id': 123}}}}

# %%
nes = {'company': {'department': {'employee': {'name': 'John', 'id': 123}}}}
nes
# Out:
# {'company': {'department': {'employee': {'name': 'John', 'id': 123}}}}

# %%
# 20: Access employee name from 3-level nested dictionary

# %%
nes = {'company': {'department': {'employee': {'name': 'John', 'id': 123}}}}
print(nes['company']['department']['employee']['name'])
# Out:
# John

# %%
# 21: Create a dictionary with mixed data types: {'int': 42, 'float': 3.14, 'str': 'hello', 'bool': True}

# %%
mix = {'int': 42, 'float': 3.14, 'str': 'hello', 'bool': True}
mix
# Out:
# {'int': 42, 'float': 3.14, 'str': 'hello', 'bool': True}

# %%
#22 Check data type of each value in mixed dictionary

# %%
mix = {'int': 42, 'float': 3.14, 'str': 'hello', 'bool': True}
for key ,values in mix.items():
    print(key,type(values))
# Out:
# int <class 'int'>
# float <class 'float'>
# str <class 'str'>
# bool <class 'bool'>

# %%
# 23: Create a dictionary with function values: {'len': len, 'str': str, 'int': int}

# %%
dic = {'len': len, 'str': str, 'int': int}
dic
# Out:
# {'len': <function len(obj, /)>, 'str': str, 'int': int}

# %%
# 24: Apply each function to "123" using dictionary

# %%
func = {'len': len,'str': str,'int': int}
for key,values in func.items():
    print(key,values("123"))
# Out:
# len 3
# str 123
# int 123

# %%
#  25: Create a dictionary with lambda functions: {'double': lambda x: x*2, 'square': lambda x: x**2}

# %%
lam = {'double': lambda x: x*2, 'square': lambda x: x**2}
lam
# Out:
# {'double': <function __main__.<lambda>(x)>,
#  'square': <function __main__.<lambda>(x)>}

# %%
# 26 Apply each lambda function to 5

# %%
lam = {'double': lambda x: x*2, 'square': lambda x: x**2}
for key,func in lam.items():
    print(key,func(5))
# Out:
# double 10
# square 25

# %%
# 27: Create a dictionary with class values: {'list': list, 'dict': dict, 'set': set}

# %%
dic =  {'list': list, 'dict': dict, 'set': set}
dic
# Out:
# {'list': list, 'dict': dict, 'set': set}

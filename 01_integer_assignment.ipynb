# %%
Calculate the product of first 10 natural numbers

# %%
res = 1 
for i in range(1,10):
    res*=i # res=res*i
print(res)
# Out:
# 362880

# %%
Find the remainder when 156 is divided by 7

# %%
a = 156 % 7
print(a)
# Out:
# 2

# %%
#Calculate the square of 25

# %%
a = 25**2
print(a)
# Out:
# 625

# %%
#Find the cube root of 125

# %%
a = 125**(1/3)
print(a)
# Out:
# 4.999999999999999

# %%
#Calculate the sum of digits in number 12345

# %%
n ="12345"
res = 0
for i in n:
    res += int(i)
print(res)
# Out:
# 15

# %%
#Check if 97 is a prime number

# %%
for i in range(2,97):
    if 97%i==0:
        print(f" 67 is not prime number")
        break
else:
     print(f" 67 is prime number")
# Out:
#  67 is prime number

# %%
#Find the factorial of 8

# %%
res = 1
for i in range(1,9):
    res *= i 
print(res)
# Out:
# 40320

# %%
 #Calculate the average of numbers: 15, 23, 31, 42, 56

# %%
n = 15+23+31+42+56
i = n /5
i
# Out:
# 33.4

# %%
n = (15, 23, 31, 42, 56)
res =0
for i in n:
    res+=i
avg=res /len(n)
print(avg)
# Out:
# 33.4

# %%
#Find the greatest common divisor (GCD) of 48 and 36

# %%
a = 48
b = 36
num = b
while num >0:
    res= a%num
    if res ==0:
        print(f"gcd of {a,b} = {num}")
        break
    num = res
# Out:
# gcd of (48, 36) = 12

# %%
a = 40
b =  50
num = b
while num >0:
    res= a%num
    if res ==0:
        print(f" gdt of {a,b} = {num} ")
        break
    num = res
# Out:
#  gdt of (40, 50) = 40

# %%
# Calculate the sum of first 20 odd numbers

# %%
res =0
for i in range (1,40,2):
    res+=i 
print(res)
# Out:
# 400

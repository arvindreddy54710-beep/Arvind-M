# %%
#Calculate the average of 3.14, 2.718, 1.618, 0.577

# %%
a = 3.14, 2.718, 1.618, 0.577
res =0
n =int(input(" enter the number:-"))
for i in (a):
    res +=i
avg = res/n
print(avg)
# Out:
#  enter the number:-9
# 0.8947777777777779

# %%
#Convert 98.6 Fahrenheit to Celsius (F = C * 9/5 + 32)

# %%
n = 98.6
f = (n - 32) * (5/9)
          
print(f)
# Out:
# 37.0

# %%
#  Calculate the compound interest on $1000 at 5.5% for 3 years

# %%
n = 1000
m = 5.5
o = 3*12
i = n % m
j = i * o
print(j)
# Out:
# 162.0

# %%
A=1000×(1+0.055) 
3

# %%
p =1000
r=5.5
t =3
a = p* (1+r/100)**t
ci = a-p
print(a , ci)
# Out:
# 1174.2413749999998 174.24137499999983

# %%
#Find the hypotenuse of a right triangle with sides 3.5 and 4.2 ()

# %%
import math
a = 3.5
b = 4.2

hypo= (3.5**2 + 4.2**2)**0.5
print(hypo)
# Out:
# 5.4671747731346585

# %%
#Calculate the volume of a sphere with radius 7.8 /(volume = (4/3) · π · r3)

# %%
import math
r = float(input("enter the number of sphere:-"))
volum = (4/3)* math.pi * (r**3)
print(volum)
# Out:
# enter the number of sphere:-7.8
# 1987.798769261791

# %%
# Round 3.14159 to 3 decimal places

# %%
num = 3.14159
dec = round(num , 3)
print(dec)
# Out:
# 3.142

# %%
# Calculate the percentage: 45 out of 67

# %%
a = 45
b = 67
per = a / b * 100
print(per)
# Out:
# 67.16417910447761

# %%
# Find the square root of 23.456

# %%
a = 23.456
squ = a **0.5
print(squ)
# Out:
# 4.843139477652899

# %%
#  Calculate the simple interest: Principal=2500, Rate=6.5%, Time=2.5 years   p x r x t /100

# %%
p = 2500
r = 6.5
t = 2.5
a = (p* r*t) / 100
print(a)
# Out:
# 406.25

# %%
# Convert 45.7 degrees to radians

# %%
num = 3.142 * 45.7 / 180
# deg = num /180
# deg
num
# Out:
# 0.797718888888889

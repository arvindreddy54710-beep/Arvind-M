# %%
# 1: Create a variable and assign None to it

# %%
x = None
print(x)
# Out:
# None

# %%
# 2: Check if None equals None

# %%
x = None
y = None
if x == y:
    print("it is equal")
# Out:
# it is equal

# %%
#  3: Check if None is None

# %%
c = None
d =None
if None is None:
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
# 4: Check if 0 is None

# %%
if 0 is None:
    print("true")
else:
    print("fales")
# Out:
# fales
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\Manjula\AppData\Local\Temp\ipykernel_21280\859951443.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if 0 is None:

# %%
# 5: Check if empty string is None

# %%
if "" is None:
    print("true")
else:
    print("fales")
# Out:
# fales
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\Manjula\AppData\Local\Temp\ipykernel_21280\1618424401.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if "" is None:

# %%
# 6: Check if False is None

# %%
if False is None:
    print("true")
else:
    print("fales")
# Out:
# fales

# %%
# 7: Check if empty list is None

# %%
a =[]
if a is None:
    print("true")
else:
    print("fales")
# Out:
# fales

# %%
#  8: Check if empty dictionary is None

# %%
dic ={}
if dic is None:
    print("true")
else:
    print("fales")
# Out:
# fales

# %%
# 9: Check if empty tuple is None

# %%
tup = ()
if tup is None:
    print("true")
else:
    print("fales")
# Out:
# fales

# %%
sets=set()
if sets is None:
    print("true")
else:
    print("fales")
# Out:
# fales
